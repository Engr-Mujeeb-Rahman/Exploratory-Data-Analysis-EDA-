# %% [markdown]
# # Data Analysis On Covid 19 DataSet

# %% [markdown]
#  We will cover the following terms to complete this project

# %% [markdown]
# ##    import Libries

# %% [markdown]
# ## Load Data

# %% [markdown]
# ## Collect All Basic Info Of The Data set

# %% [markdown]
# ## Finding The missing Value and Mange them

# %% [markdown]
# ## Finding The Duplliacte Value and Manage them

# %% [markdown]
# # Cover the following Question about the Data Set

# %% [markdown]
# ####             Q. 1) Show the number of Confirmed, Deaths and Recovered cases in each Region.
# ####             Q. 2) Remove all the records where the Confirmed Cases is Less Than 1000.
# ####             Q. 3) In which Date, maximum number of Confirmed cases were recorded ?
# ####             Q. 4) In which Date, minimum number of Deaths cases were recorded ?
# ####             Q. 5) How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?
# ####             Q. 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.
# ####             Q. 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %% [markdown]
# # import Libries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
Data=pd.read_csv("day_wise.csv")
Data
# Out:
#           Date   Confirmed    Deaths  Recovered     Active  New cases  \
# 0    1/22/2020       555.0      17.0       28.0      510.0        0.0
# 1    1/23/2020       654.0      18.0       30.0      606.0       99.0
# 2    1/24/2020       941.0      26.0       36.0      879.0      287.0
# 3    1/25/2020      1434.0      42.0       39.0     1353.0      493.0
# 4    1/26/2020      2118.0      56.0       52.0     2010.0      684.0
# ..         ...         ...       ...        ...        ...        ...
# 184  7/24/2020  15791645.0  639650.0  8939705.0  6212290.0   281164.0
# 185  7/25/2020  16047190.0  644517.0  9158743.0  6243930.0   255545.0
# 186  7/26/2020  16251796.0  648621.0  9293464.0  6309711.0   204606.0
# 187  7/27/2020  16480485.0  654036.0  9468087.0  6358362.0   228693.0
# 188        NaN         NaN       NaN        NaN        NaN        NaN
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
Save_Data=Data
Save_Data
# Out:
#           Date   Confirmed    Deaths  Recovered     Active  New cases  \
# 0    1/22/2020       555.0      17.0       28.0      510.0        0.0
# 1    1/23/2020       654.0      18.0       30.0      606.0       99.0
# 2    1/24/2020       941.0      26.0       36.0      879.0      287.0
# 3    1/25/2020      1434.0      42.0       39.0     1353.0      493.0
# 4    1/26/2020      2118.0      56.0       52.0     2010.0      684.0
# ..         ...         ...       ...        ...        ...        ...
# 184  7/24/2020  15791645.0  639650.0  8939705.0  6212290.0   281164.0
# 185  7/25/2020  16047190.0  644517.0  9158743.0  6243930.0   255545.0
# 186  7/26/2020  16251796.0  648621.0  9293464.0  6309711.0   204606.0
# 187  7/27/2020  16480485.0  654036.0  9468087.0  6358362.0   228693.0
# 188        NaN         NaN       NaN        NaN        NaN        NaN
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# # Collect All Basic Info Of The Data set

# %%
Data.shape
# Out:
# (189, 12)

# %%
Data.count()
# Out:
# Date                      188
# Confirmed                 188
# Deaths                    188
# Recovered                 188
# Active                    188
# New cases                 188
# New deaths                188
# New recovered             188
# Deaths / 100 Cases        188
# Recovered / 100 Cases     188
# Deaths / 100 Recovered    188
# No. of countries          188
# dtype: int64

# %%
Data.dtypes
# Out:
# Date                       object
# Confirmed                 float64
# Deaths                    float64
# Recovered                 float64
# Active                    float64
# New cases                 float64
# New deaths                float64
# New recovered             float64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# No. of countries          float64
# dtype: object

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    float64
#  2   Deaths                  188 non-null    float64
#  3   Recovered               188 non-null    float64
#  4   Active                  188 non-null    float64
#  5   New cases               188 non-null    float64
#  6   New deaths              188 non-null    float64
#  7   New recovered           188 non-null    float64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    float64
# dtypes: float64(11), object(1)
# memory usage: 17.8+ KB

# %% [markdown]
# # Finding The missing Value and Mange them

# %%
Data.isnull().sum()
# Out:
# Date                      1
# Confirmed                 1
# Deaths                    1
# Recovered                 1
# Active                    1
# New cases                 1
# New deaths                1
# New recovered             1
# Deaths / 100 Cases        1
# Recovered / 100 Cases     1
# Deaths / 100 Recovered    1
# No. of countries          1
# dtype: int64

# %% [markdown]
# #### Drop the missing Value in each columns

# %%
Data=Data.dropna()
Data
# Out:
#           Date   Confirmed    Deaths  Recovered     Active  New cases  \
# 0    1/22/2020       555.0      17.0       28.0      510.0        0.0
# 1    1/23/2020       654.0      18.0       30.0      606.0       99.0
# 2    1/24/2020       941.0      26.0       36.0      879.0      287.0
# 3    1/25/2020      1434.0      42.0       39.0     1353.0      493.0
# 4    1/26/2020      2118.0      56.0       52.0     2010.0      684.0
# ..         ...         ...       ...        ...        ...        ...
# 183  7/23/2020  15510481.0  633506.0  8710969.0  6166006.0   282756.0
# 184  7/24/2020  15791645.0  639650.0  8939705.0  6212290.0   281164.0
# 185  7/25/2020  16047190.0  644517.0  9158743.0  6243930.0   255545.0
# 186  7/26/2020  16251796.0  648621.0  9293464.0  6309711.0   204606.0
# 187  7/27/2020  16480485.0  654036.0  9468087.0  6358362.0   228693.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
#  There is only one row which we are remove from the data set

# %%
Data.isnull().sum()
# Out:
# Date                      0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# No. of countries          0
# dtype: int64

# %% [markdown]
#  now there is no any missing value in each columns

# %% [markdown]
# # Finding The Duplliacte Value and Manage them

# %%
Duplicate_rows=Data[Data.duplicated()]
Duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Date, Confirmed, Deaths, Recovered, Active, New cases, New deaths, New recovered, Deaths / 100 Cases, Recovered / 100 Cases, Deaths / 100 Recovered, No. of countries]
# Index: []

# %% [markdown]
#  there is no any dupliacte rows in the data set

# %% [markdown]
# # Cover the following Question about the Data Set

# %% [markdown]
# # ============================================================

# %% [markdown]
# #### Q. 1) Show the number of Confirmed, Deaths and Recovered cases in each Data.

# %%
Data.head()
# Out:
#         Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  1/22/2020      555.0    17.0       28.0   510.0        0.0         0.0
# 1  1/23/2020      654.0    18.0       30.0   606.0       99.0         1.0
# 2  1/24/2020      941.0    26.0       36.0   879.0      287.0         8.0
# 3  1/25/2020     1434.0    42.0       39.0  1353.0      493.0        16.0
# 4  1/26/2020     2118.0    56.0       52.0  2010.0      684.0        14.0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            0.0                3.06                   5.05
# 1            2.0                2.75                   4.59
# 2            6.0                2.76                   3.83
# 3            3.0                2.93                   2.72
# 4           13.0                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71               6.0
# 1                   60.00               8.0
# ...

# %%
Data.groupby("Date").sum()
# Out:
#             Confirmed    Deaths  Recovered     Active  New cases  New deaths  \
# Date
# 1/22/2020       555.0      17.0       28.0      510.0        0.0         0.0
# 1/23/2020       654.0      18.0       30.0      606.0       99.0         1.0
# 1/24/2020       941.0      26.0       36.0      879.0      287.0         8.0
# 1/25/2020      1434.0      42.0       39.0     1353.0      493.0        16.0
# 1/26/2020      2118.0      56.0       52.0     2010.0      684.0        14.0
# ...               ...       ...        ...        ...        ...         ...
# 7/5/2020   11454847.0  534150.0  6105546.0  4815151.0   182695.0      3445.0
# 7/6/2020   11622190.0  537947.0  6228768.0  4855475.0   167343.0      3797.0
# 7/7/2020   11833034.0  544054.0  6373513.0  4915467.0   210844.0      6107.0
# 7/8/2020   12044836.0  549373.0  6531016.0  4964447.0   211802.0      5319.0
# 7/9/2020   12273063.0  554831.0  6665237.0  5052995.0   228227.0      5458.0
#
# ...

# %% [markdown]
#  Now we having need to find out olny Confirmed,Deaths and Recovered cases

# %%
Data.groupby("Date")[["Confirmed", "Deaths","Recovered"]].sum()
# Out:
#             Confirmed    Deaths  Recovered
# Date
# 1/22/2020       555.0      17.0       28.0
# 1/23/2020       654.0      18.0       30.0
# 1/24/2020       941.0      26.0       36.0
# 1/25/2020      1434.0      42.0       39.0
# 1/26/2020      2118.0      56.0       52.0
# ...               ...       ...        ...
# 7/5/2020   11454847.0  534150.0  6105546.0
# 7/6/2020   11622190.0  537947.0  6228768.0
# 7/7/2020   11833034.0  544054.0  6373513.0
# 7/8/2020   12044836.0  549373.0  6531016.0
# 7/9/2020   12273063.0  554831.0  6665237.0
#
# [188 rows x 3 columns]

# %% [markdown]
# #### Q. 2) Remove all the records where the Confirmed Cases is Less Than 1000

# %%
remove_Confirmed_Cases=Data[Data["Confirmed"]<1000]
remove_Confirmed_Cases
# Out:
#         Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  1/22/2020      555.0    17.0       28.0   510.0        0.0         0.0
# 1  1/23/2020      654.0    18.0       30.0   606.0       99.0         1.0
# 2  1/24/2020      941.0    26.0       36.0   879.0      287.0         8.0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            0.0                3.06                   5.05
# 1            2.0                2.75                   4.59
# 2            6.0                2.76                   3.83
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71               6.0
# 1                   60.00               8.0
# 2                   72.22               9.0

# %%
# Now remove this from the dataset
listindex=list()
for i in remove_Confirmed_Cases.index:
    listindex.append(i)

listindex
# Out:
# [0, 1, 2]

# %%
Data=Data.drop(listindex)
Data
# Out:
#           Date   Confirmed    Deaths  Recovered     Active  New cases  \
# 3    1/25/2020      1434.0      42.0       39.0     1353.0      493.0
# 4    1/26/2020      2118.0      56.0       52.0     2010.0      684.0
# 5    1/27/2020      2927.0      82.0       61.0     2784.0      809.0
# 6    1/28/2020      5578.0     131.0      107.0     5340.0     2651.0
# 7    1/29/2020      6166.0     133.0      125.0     5908.0      588.0
# ..         ...         ...       ...        ...        ...        ...
# 183  7/23/2020  15510481.0  633506.0  8710969.0  6166006.0   282756.0
# 184  7/24/2020  15791645.0  639650.0  8939705.0  6212290.0   281164.0
# 185  7/25/2020  16047190.0  644517.0  9158743.0  6243930.0   255545.0
# 186  7/26/2020  16251796.0  648621.0  9293464.0  6309711.0   204606.0
# 187  7/27/2020  16480485.0  654036.0  9468087.0  6358362.0   228693.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
#  Here you can see that we can sucssfilly remove the data

# %%
Data[Data["Confirmed"]<1000]
# Out:
# Empty DataFrame
# Columns: [Date, Confirmed, Deaths, Recovered, Active, New cases, New deaths, New recovered, Deaths / 100 Cases, Recovered / 100 Cases, Deaths / 100 Recovered, No. of countries]
# Index: []

# %% [markdown]
# #### Q. 3) In which Date, maximum number of Confirmed cases were recorded ?

# %%
Data.groupby("Date")["Confirmed"].sum().sort_values(ascending=False)
# Out:
# Date
# 7/27/2020    16480485.0
# 7/26/2020    16251796.0
# 7/25/2020    16047190.0
# 7/24/2020    15791645.0
# 7/23/2020    15510481.0
#                 ...
# 1/29/2020        6166.0
# 1/28/2020        5578.0
# 1/27/2020        2927.0
# 1/26/2020        2118.0
# 1/25/2020        1434.0
# Name: Confirmed, Length: 185, dtype: float64

# %% [markdown]
#  second way to find maximum Confirmed cases

# %%
new_Data=Data.sort_values(by="Confirmed",ascending=False)
new_Data
# Out:
#           Date   Confirmed    Deaths  Recovered     Active  New cases  \
# 187  7/27/2020  16480485.0  654036.0  9468087.0  6358362.0   228693.0
# 186  7/26/2020  16251796.0  648621.0  9293464.0  6309711.0   204606.0
# 185  7/25/2020  16047190.0  644517.0  9158743.0  6243930.0   255545.0
# 184  7/24/2020  15791645.0  639650.0  8939705.0  6212290.0   281164.0
# 183  7/23/2020  15510481.0  633506.0  8710969.0  6166006.0   282756.0
# ..         ...         ...       ...        ...        ...        ...
# 7    1/29/2020      6166.0     133.0      125.0     5908.0      588.0
# 6    1/28/2020      5578.0     131.0      107.0     5340.0     2651.0
# 5    1/27/2020      2927.0      82.0       61.0     2784.0      809.0
# 4    1/26/2020      2118.0      56.0       52.0     2010.0      684.0
# 3    1/25/2020      1434.0      42.0       39.0     1353.0      493.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
new_Data.head(1)
# Out:
#           Date   Confirmed    Deaths  Recovered     Active  New cases  \
# 187  7/27/2020  16480485.0  654036.0  9468087.0  6358362.0   228693.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 187      5415.0       174623.0                3.97                  57.45
#
#      Deaths / 100 Recovered  No. of countries
# 187                    6.91             187.0

# %% [markdown]
#  Here in above data there are Maximum number of Confirmed Cases

# %% [markdown]
# #### Q. 4) In which Date, minimum number of Deaths cases were recorded ?

# %%
new_Data_For_Deaths=Data.sort_values(by="Deaths",ascending=True)

# %%
new_Data_For_Deaths.head(1)
# Out:
#         Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 3  1/25/2020     1434.0    42.0       39.0  1353.0      493.0        16.0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 3            3.0                2.93                   2.72
#
#    Deaths / 100 Recovered  No. of countries
# 3                  107.69              11.0

# %% [markdown]
# #### Q. 5) How many Confirmed, Deaths & Recovered cases were reported in  7/25/2020?

# %%
Data[Data["Date"]=="7/25/2020"]
# Out:
#           Date   Confirmed    Deaths  Recovered     Active  New cases  \
# 185  7/25/2020  16047190.0  644517.0  9158743.0  6243930.0   255545.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 185      4867.0       219038.0                4.02                  57.07
#
#      Deaths / 100 Recovered  No. of countries
# 185                    7.04             187.0

# %% [markdown]
# #### Q. 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
new_Data=Data.sort_values(by="Confirmed",ascending=True)
new_Data
# Out:
#           Date   Confirmed    Deaths  Recovered     Active  New cases  \
# 3    1/25/2020      1434.0      42.0       39.0     1353.0      493.0
# 4    1/26/2020      2118.0      56.0       52.0     2010.0      684.0
# 5    1/27/2020      2927.0      82.0       61.0     2784.0      809.0
# 6    1/28/2020      5578.0     131.0      107.0     5340.0     2651.0
# 7    1/29/2020      6166.0     133.0      125.0     5908.0      588.0
# ..         ...         ...       ...        ...        ...        ...
# 183  7/23/2020  15510481.0  633506.0  8710969.0  6166006.0   282756.0
# 184  7/24/2020  15791645.0  639650.0  8939705.0  6212290.0   281164.0
# 185  7/25/2020  16047190.0  644517.0  9158743.0  6243930.0   255545.0
# 186  7/26/2020  16251796.0  648621.0  9293464.0  6309711.0   204606.0
# 187  7/27/2020  16480485.0  654036.0  9468087.0  6358362.0   228693.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# #### Q. 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
new_Data_for_Recover=Data.sort_values(by="Recovered",ascending=False)
new_Data_for_Recover
# Out:
#           Date   Confirmed    Deaths  Recovered     Active  New cases  \
# 187  7/27/2020  16480485.0  654036.0  9468087.0  6358362.0   228693.0
# 186  7/26/2020  16251796.0  648621.0  9293464.0  6309711.0   204606.0
# 185  7/25/2020  16047190.0  644517.0  9158743.0  6243930.0   255545.0
# 184  7/24/2020  15791645.0  639650.0  8939705.0  6212290.0   281164.0
# 183  7/23/2020  15510481.0  633506.0  8710969.0  6166006.0   282756.0
# ..         ...         ...       ...        ...        ...        ...
# 7    1/29/2020      6166.0     133.0      125.0     5908.0      588.0
# 6    1/28/2020      5578.0     131.0      107.0     5340.0     2651.0
# 5    1/27/2020      2927.0      82.0       61.0     2784.0      809.0
# 4    1/26/2020      2118.0      56.0       52.0     2010.0      684.0
# 3    1/25/2020      1434.0      42.0       39.0     1353.0      493.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...
